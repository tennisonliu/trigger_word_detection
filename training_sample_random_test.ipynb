# %%
import numpy as np
from pydub import AudioSegment
import random
import sys
import io
import os
import glob
import IPython
from td_utils import *
import matplotlib.pyplot as plt

# %%
index = 150
x = graph_spectrogram("/home/liu181/Desktop/sample_generator/training_samples/sample_"+str(index)+ ".wav")
y = np.load("/home/liu181/Desktop/sample_generator/IndividualSamples_Y/sample_" + str(index)+".npy")

# %%
IPython.display.Audio("/home/liu181/Desktop/sample_generator/training_samples/sample_"+str(index)+ ".wav")
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plt.plot(y[0])
